                        0.414, 0.53, 0.0647, 0.0498, 0.102, 0.752, 0.5, 0.0669, 0.761, 0.167,
                        0.256]

# %%
#merge 
# fn_origin_total = fn_origin + fn_un_origin
# fn_modify_total = fn_modify + fn_un_modify

z_total_origin = z_origin + z_unwatermark_origin
z_total_modify = z_modify + z_unwatermark_modify

fn_origin_total = [scipy.stats.norm.sf(4-z) for z in z_total_origin]
# set the z threshold higher for modify method.
fn_modify_total = [scipy.stats.norm.sf(4.2-z) for z in z_total_modify]

# %%
import scipy.stats

# print(scipy.stats.norm.sf(11.8))
# fp_origin = []
# fp_modify = []
# for score_origin, score_modify in zip(z_origin, z_modify):
#     fp_origin.append(scipy.stats.norm.sf(score_origin))
#     fp_modify.append(scipy.stats.norm.sf(score_modify))

fp_origin_total = fp_origin + fp_unwatermark_origin
fp_modify_total = fp_modify + fp_unwatermark_modify

# %%
len(fn_origin_total)
len(fn_modify_total)
# Out:
# 102

# %% [markdown]
# plot

# %% [markdown]
# Total

# %%
import matplotlib.pyplot as plt

# Plot both lines
plt.scatter(fp_origin_total, fn_origin_total, label='origin')
plt.scatter(fp_modify_total, fn_modify_total, label='modify')

plt.xticks([i / 10 for i in range(1, 11)])
# plt.scatter(fp_unwatermark_origin, fn_un_origin, label='origin')
# plt.scatter(fp_unwatermark_modify, fn_un_modify, label='modify')

# threshold = 1e-2
# filtered_origin = [(fp, fn) for fp, fn in zip(fp_unwatermark_origin, fn_un_origin) if fp >= threshold]
# filtered_modify = [(fp, fn) for fp, fn in zip(fp_unwatermark_modify, fn_un_modify) if fp >= threshold]

# # Unzip filtered data
# fp_filtered_origin, fn_filtered_origin = zip(*filtered_origin)
# fp_filtered_modify, fn_filtered_modify = zip(*filtered_modify)

# # Plot
# plt.scatter(fp_filtered_origin, fn_filtered_origin, label='origin')
# plt.scatter(fp_filtered_modify, fn_filtered_modify, label='modify')

# Add labels and title
plt.ylabel('False Negative (Type II error)')
plt.xlabel('False Positive (Type I error)')
plt.title('Watermark rate comparison')

# plt.xscale('log')
plt.yscale('log')

# Add legend
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# FP

# %%
plt.scatter([i for i in range(len(fp_origin))], sorted(fp_origin),label='origin')
plt.scatter([i for i in range(len(fp_modify))], sorted(fp_modify), label='modify')

# Add labels and title
plt.ylabel('False positive (Type I error)')
plt.xlabel('Cases index')
plt.title('Watermark FP rate comparison')

# plt.xscale('log')
plt.yscale('log')

# Add legend
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# FN

# %%
plt.scatter([i for i in range(len(fn_un_origin))], sorted(fn_un_origin),label='origin')
plt.scatter([i for i in range(len(fn_un_modify))], sorted(fn_un_modify), label='modify')

# Add labels and title
plt.ylabel('False positive (Type I error)')
plt.xlabel('Cases index')
plt.title('Watermark FN rate comparison')

# plt.xscale('log')
plt.yscale('log')

# Add legend
plt.legend()

# Show plot
plt.show()
